# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %%
doc = nlp("dog cat banana kem faizan sdfg sdfghn")

for token in doc:
    print(f"{token.text} Vector: {token.has_vector} OOV: {token.is_oov}")
# Out:
# dog Vector: True OOV: False
# cat Vector: True OOV: False
# banana Vector: True OOV: False
# kem Vector: True OOV: False
# faizan Vector: True OOV: False
# sdfg Vector: False OOV: True
# sdfghn Vector: False OOV: True

# %%
doc[0].vector.shape
# Out:
# (300,)

# %%
base_token= nlp("bread")
base_token.vector.shape
# Out:
# (300,)

# %%
doc = nlp("bread sandwich burger car tiger human wheat")

for token in doc:
    print(f"{token.text} - {base_token.text} - {token.similarity(base_token)}")
# Out:
# bread - bread - 1.0
# sandwich - bread - 0.687455952167511
# burger - bread - 0.544037401676178
# car - bread - 0.16441147029399872
# tiger - bread - 0.14492353796958923
# human - bread - 0.21103662252426147
# wheat - bread - 0.6572456359863281

# %%
def printSimilarity(base_word, words_to_compare):
    base_token = nlp(base_word)
    doc = nlp(words_to_compare)

    for token in doc:
        print(f"{token.text} - {base_token.text} - {token.similarity(base_token)}")

# %%
printSimilarity('iphone', 'apple gmail iphone dog elephant')
# Out:
# apple - iphone - 0.6339781284332275
# gmail - iphone - 0.45783859491348267
# iphone - iphone - 0.9999999403953552
# dog - iphone - 0.1743103712797165
# elephant - iphone - 0.15216436982154846

# %%
king = nlp.vocab["king"].vector
man = nlp.vocab["man"].vector
woman = nlp.vocab["woman"].vector
queen = nlp.vocab["queen"].vector

result = king - man + woman

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity([result], [queen])
# Out:
# array([[0.78808445]], dtype=float32)
