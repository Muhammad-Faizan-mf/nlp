# %%
import spacy

nlp = spacy.blank("en")
doc  = nlp("I M.Faizan love to eat cheese pasta and it costs me $6 per meal.")
for token in doc:
    print(token)
# Out:
# I
# M.Faizan
# love
# to
# eat
# cheese
# pasta
# and
# it
# costs
# me
# $
# 6
# per
# meal
# .

# %%
doc[1]
# Out:
# M.Faizan

# %%
token = doc[1]
token.text
# Out:
# 'M.Faizan'

# %%
dir(token)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
type(token)
# Out:
# spacy.tokens.token.Token

# %%
nlp.pipe_names
# Out:
# []

# %%
span = doc[:5]
span
# Out:
# I M.Faizan love to eat

# %%
type(span)
# Out:
# spacy.tokens.span.Span

# %%
doc = nlp("Faizan gave two $ to peter")
token0 =doc[0]
token0
# Out:
# Faizan

# %%
token0.is_alpha
# Out:
# True

# %%
token0.is_alpha
# Out:
# True

# %%
token3 = doc[3]
token3
# Out:
# $

# %%
token3.is_alpha
# Out:
# False

# %%
token3.is_alpha
# Out:
# False

# %%
token3.is_currency
# Out:
# True

# %%
for token in doc:
    print(
        token, "==>","index: ", token.i, "is_alpha", token.is_alpha, "is_punct", token.is_punct, "like_num",token.like_num,"is_currency", token.is_currency 
    )
# Out:
# Faizan ==> index:  0 is_alpha True is_punct False like_num False is_currency False
# gave ==> index:  1 is_alpha True is_punct False like_num False is_currency False
# two ==> index:  2 is_alpha True is_punct False like_num True is_currency False
# $ ==> index:  3 is_alpha False is_punct False like_num False is_currency True
# to ==> index:  4 is_alpha True is_punct False like_num False is_currency False
# peter ==> index:  5 is_alpha True is_punct False like_num False is_currency False

# %%
with open("students.txt") as f:
    text = f.readlines()

text
# Out:
# ['Dayton high school, 5th grade students details\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'John   5 June, 1882    John@gmail.com\n',
#  'Aly\t12 April, 2001  Aly@yahoo.com\n',
#  'Tim  24 June, 1998   Tim@outlook.com \n',
#  'Joe      1 May, 1997    joe@yahoo.com']

# %%
text = " ".join(text)
text
# Out:
# 'Dayton high school, 5th grade students details\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n John   5 June, 1882    John@gmail.com\n Aly\t12 April, 2001  Aly@yahoo.com\n Tim  24 June, 1998   Tim@outlook.com \n Joe      1 May, 1997    joe@yahoo.com'

# %%
doc = nlp(text)
emails = []

for token in doc:
    if token.like_email:
        emails.append(token.text)

emails
# Out:
# ['John@gmail.com', 'Aly@yahoo.com', 'Tim@outlook.com', 'joe@yahoo.com']

# %%
from spacy.symbols import ORTH

nlp = spacy.blank('en')
doc = nlp("gimme two chilled coca cola please!")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'two', 'chilled', 'coca', 'cola', 'please', '!']

# %%
nlp.tokenizer.add_special_case("gimme",[
    {ORTH: "gim"},
    {ORTH: "me"}
])
doc = nlp("gimme two chilled coca cola please!")

tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'two', 'chilled', 'coca', 'cola', 'please', '!']

# %%
doc = nlp("I love to eat pasta. I also love to eat burger.")
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 doc = nlp("I love to eat pasta. I also love to eat burger.")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/spacy/tokens/doc.pyx:926, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp.pipeline
# Out:
# []

# %%
nlp.add_pipe('sentencizer')

# %%
doc = nlp("I love to eat pasta. I also love to eat burger.")
for sentence in doc.sents:
    print(sentence)
# Out:
# I love to eat pasta.
# I also love to eat burger.

# %%
nlp.pipeline
# Out:
# [('sentencizer', <spacy.pipeline.sentencizer.Sentencizer at 0x113d96b90>)]

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

doc = nlp(text)
references_to_web = []
for token in doc:
    if token.like_url:
        references_to_web.append(token.text)

references_to_web
# Out:
# ['http://www.data.gov/',
#  'http://www.science',
#  'http://data.gov.uk/.',
#  'http://www3.norc.org/gss+website/',
#  'http://www.europeansocialsurvey.org/.']

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"
doc = nlp(transactions)

for token in doc:
    if token.like_num and doc[token.i+1].is_currency:
        print(token.text, doc[token.i+1].text,)
# Out:
# two $
# 500 €
