# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
text = '''
Thor: Love and Thunder is a 2022 American superhero film based on Marvel Comics featuring the character Thor, produced by Marvel Studios and 
distributed by Walt Disney Studios Motion Pictures. It is the sequel to Thor: Ragnarok (2017) and the 29th film in the Marvel Cinematic Universe (MCU).
The film is directed by Taika Waititi, who co-wrote the script with Jennifer Kaytin Robinson, and stars Chris Hemsworth as Thor alongside Christian Bale, Tessa Thompson,
Jaimie Alexander, Waititi, Russell Crowe, and Natalie Portman. In the film, Thor attempts to find inner peace, but must return to action and recruit Valkyrie (Thompson),
Korg (Waititi), and Jane Foster (Portman)—who is now the Mighty Thor—to stop Gorr the God Butcher (Bale) from eliminating all gods.
'''


def stop_words(text):
    doc = nlp(text)
    stop_words = []
    for token in doc:
        if token.is_stop:
            stop_words.append(token.text)
    return stop_words

stop_words = (stop_words(text))
stop_words
# Out:
# ['and',
#  'is',
#  'a',
#  'on',
#  'the',
#  'by',
#  'and',
#  'by',
#  'It',
#  'is',
#  'the',
#  'to',
#  'and',
#  'the',
#  'in',
#  'the',
#  'The',
#  'is',
#  'by',
#  'who',
#  'the',
#  'with',
#  'and',
#  'as',
#  'and',
#  'In',
#  'the',
#  'to',
#  'but',
#  'must',
#  'to',
#  'and',
#  'and',
#  'is',
#  'now',
#  'the',
#  'to',
#  'the',
#  'from',
#  'all']

# %%
len(stop_words)
# Out:
# 40

# %%
per_stop_words = (len(stop_words)/len(text))*100
print(f"Percentage of stopwords is {per_stop_words}%")
# Out:
# Percentage of stopwords is 5.215123859191656%

# %%
def pre_process(text):
    doc = nlp(text)
    no_stop_words = [token.text for token in doc if not token.is_stop]
    return " ".join(no_stop_words)

nlp.vocab['not'].is_stop = False

pos_text = "Food was good"
neg_text = "Food was not good"
print(f"Positive text: {pre_process(pos_text)}")
print(f"Negative text: {pre_process(neg_text)}")
# Out:
# Positive text: Food good
# Negative text: Food not good

# %%
text = '''
Thor: Love and Thunder is a 2022 American superhero film based on Marvel Comics featuring the character Thor, produced by Marvel Studios and 
distributed by Walt Disney Studios Motion Pictures. It is the sequel to Thor: Ragnarok (2017) and the 29th film in the Marvel Cinematic Universe (MCU).
The film is directed by Taika Waititi, who co-wrote the script with Jennifer Kaytin Robinson, and stars Chris Hemsworth as Thor alongside Christian Bale, Tessa Thompson,
Jaimie Alexander, Waititi, Russell Crowe, and Natalie Portman. In the film, Thor attempts to find inner peace, but must return to action and recruit Valkyrie (Thompson),
Korg (Waititi), and Jane Foster (Portman)—who is now the Mighty Thor—to stop Gorr the God Butcher (Bale) from eliminating all gods.
'''

doc = nlp(text)
no_stop_tokens = []
for token in doc:
    if not token.is_stop and not token.is_punct:
        no_stop_tokens.append(token.text)


token_freq = {}

for token in no_stop_tokens:
    if token != '\n' and token != ' ':
        if token in token_freq:
            token_freq[token] += 1
        else:
            token_freq[token] = 1

max_freq_word = max(token_freq.keys(), key=(lambda key:token_freq[key]))
max_freq_word
# Out:
# 'Thor'
