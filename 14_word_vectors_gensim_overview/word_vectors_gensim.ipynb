# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

# %%
wv.similarity(w1='great', w2='good')
# Out:
# np.float32(0.72915095)

# %%
wv.most_similar('good')
# Out:
# [('great', 0.7291510105133057),
#  ('bad', 0.7190051078796387),
#  ('terrific', 0.6889115571975708),
#  ('decent', 0.6837347745895386),
#  ('nice', 0.6836092472076416),
#  ('excellent', 0.644292950630188),
#  ('fantastic', 0.6407778263092041),
#  ('better', 0.6120728850364685),
#  ('solid', 0.5806034803390503),
#  ('lousy', 0.576420247554779)]

# %%
wv.most_similar('dog')
# Out:
# [('dogs', 0.8680489659309387),
#  ('puppy', 0.8106428384780884),
#  ('pit_bull', 0.7803961038589478),
#  ('pooch', 0.7627376914024353),
#  ('cat', 0.7609456777572632),
#  ('golden_retriever', 0.7500902414321899),
#  ('German_shepherd', 0.7465174198150635),
#  ('Rottweiler', 0.7437615394592285),
#  ('beagle', 0.7418621778488159),
#  ('pup', 0.7406911253929138)]

# %%
wv.most_similar(positive=['king', 'woman'], negative=['man'], topn=5)
# Out:
# [('queen', 0.7118192911148071),
#  ('monarch', 0.6189674735069275),
#  ('princess', 0.5902431011199951),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321243286133)]

# %%
wv.most_similar(positive=['france', 'berlin'], negative=['paris'], topn=10)
# Out:
# [('germany', 0.5094343423843384),
#  ('european', 0.48650455474853516),
#  ('german', 0.4714890420436859),
#  ('austria', 0.46964022517204285),
#  ('swedish', 0.4645182490348816),
#  ('Wissenschaft', 0.45328807830810547),
#  ('denmark', 0.4477354884147644),
#  ('München', 0.4438532292842865),
#  ('europe', 0.4420619606971741),
#  ('belgium', 0.43769749999046326)]

# %%
wv.doesnt_match(['facebook','insta','google','dog'])
# Out:
# 'dog'

# %%
wv.doesnt_match(["dog", "cat", "google", "mouse"])
# Out:
# 'google'

# %%
glv = api.load('glove-twitter-25')
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
glv.most_similar('good')
# Out:
# [('too', 0.9648016691207886),
#  ('day', 0.9533665180206299),
#  ('well', 0.9503171443939209),
#  ('nice', 0.9438973665237427),
#  ('better', 0.9425961375236511),
#  ('fun', 0.941892683506012),
#  ('much', 0.9413354992866516),
#  ('this', 0.9387555122375488),
#  ('hope', 0.9383508563041687),
#  ('great', 0.9378516674041748)]

# %%
glv.doesnt_match("breakfast cereal dinner lunch".split())
# Out:
# 'cereal'

# %%
glv.doesnt_match("cat facebook google yahoo ".split())
# Out:
# 'cat'

# %%
glv.doesnt_match("banana grapes orange human".split())
# Out:
# 'human'
